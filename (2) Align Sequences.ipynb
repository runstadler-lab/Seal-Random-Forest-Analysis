# %%
from Bio.Align.Applications import ClustalOmegaCommandline

# %%
filename = 'Human and Avian H3 Sequences.fasta'
out_file = 'Human and Avian H3 Sequencess Aligned.fasta'
clustalomega_cline = ClustalOmegaCommandline(infile=filename, outfile=out_file, verbose=True, auto=True, force=True)
clustalomega_cline()
# Out:
# ('Using 1 threads\nRead 7376 sequences (type: Protein) from Human and Avian H3 Sequences.fasta\nSetting options automatically based on input sequence characteristics (might overwrite some of your options).\nUsing 165 seeds (chosen with constant stride from length sorted seqs) for mBed (from a total of 7376 sequences)\nCalculating pairwise ktuple-distances...\nKtuple-distance calculation progress: 0 % (0 out of 1203510)\nKtuple-distance calculation progress: 1 % (14749 out of 1203510)\nKtuple-distance calculation progress: 2 % (29494 out of 1203510)\nKtuple-distance calculation progress: 3 % (36865 out of 1203510)\nKtuple-distance calculation progress: 4 % (51604 out of 1203510)\nKtuple-distance calculation progress: 5 % (66339 out of 1203510)\nKtuple-distance calculation progress: 6 % (73705 out of 1203510)\nKtuple-distance calculation progress: 7 % (88434 out of 1203510)\nKtuple-distance calculation progress: 8 % (103159 out of 1203510)\nKtuple-distance calculation progress: 9 % (11
# ...
